# %%
# autocomplete setting 
# %config IPCompleter.greedy=True

# %%
# import libs and const vals
import pandas as pd
import numpy as np
import sys
import os

FOLDER_NAME = "tatanic"
PASSENGERID = 'PassengerId'
SURVIVED = 'Survived'
PCLASS = 'Pclass'
NAME = 'Name'
SEX = 'Sex'
AGE = 'Age'
SIBSP = 'SibSp'
PARCH = 'Parch'
TICKET = 'Ticket'
FARE = 'Fare'
CABIN = 'Cabin'
EMBARKED = 'Embarked'


CSV_COLUMNS = [
    PASSENGERID,
    SURVIVED,
    PCLASS,
    NAME,
    SEX,
    AGE,
    SIBSP,
    PARCH,
    TICKET,
    FARE,
    CABIN,
    EMBARKED,
]

print("import libs and init const vals")
# Out:
# import libs and init const vals

# %%
# read dataset 
path = os.path.join(os.getcwd(), "data","titanic",  "train.csv")

df = pd.read_csv(
    path,
    sep=',',
    header=None,
    error_bad_lines=False,
    names=CSV_COLUMNS,
)
df = df.fillna(df.mean())
df = df.round()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                 Name     Sex  Age  SibSp  \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#    Parch            Ticket     Fare  Cabin  Embarked
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
a = np.array([1.0,2.0,3.0, "3", np.nan, ])
print(a)
print(a.dtype)
print(a[4].dtype)
a = np.where(type(a) == float, -1, a)
print(a)
# Out:
# ['1.0' '2.0' '3.0' '3' 'nan']
# <U32
# <U3
# ['1.0' '2.0' '3.0' '3' 'nan']

# %%
df.groupby(['Pclass', 'Sex'])['Survived'].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-5-f17c7c252dbb> in <module>()
# ----> 1 df.groupby(['Pclass', 'Sex'])['Survived'].mean()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in mean(self, *args, **kwargs)
#    1126         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1127         try:
# -> 1128             return self._cython_agg_general('mean', **kwargs)
#    1129         except GroupByError:
#    1130             raise
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     925
#     926         if len(output) == 0:
# --> 927             raise DataError('No numeric types to aggregate')
#     928
#     929         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
df = pd.DataFrame()
df["PassengerId"] = range(1,6)
df["Survived"] = None

df
# Out:
#    PassengerId Survived
# 0            1     None
# 1            2     None
# 2            3     None
# 3            4     None
# 4            5     None
